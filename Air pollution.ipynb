# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report as cr , confusion_matrix as cm
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import numpy as np

# %%
z = pd.read_csv(r"D:\SRM\Github codes\Datasets\data2\updated_pollution_dataset.csv")
z
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               6.3                 319    Moderate
# 1                               6.0                 611    Moderate
# ...

# %%
z["Air Quality"].value_counts()
# Out:
# Air Quality
# Good         2000
# Moderate     1500
# Poor         1000
# Hazardous     500
# Name: count, dtype: int64

# %%
def change(s):
    if(s == "Good"):
        return(1)
    elif(s == "Moderate"):
        return(2)
    elif(s == "Poor"):
         return(3)
    else:
        return(0)

# %%
z["Air Quality"] = z["Air Quality"].apply(change)

# %%
b = z.copy()
for i in b:
    if(b[i].dtype == "object"):
        b.drop([i], axis = 1, inplace = True)
b
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density  Air Quality
# 0                               6.3                 319            2
# 1                               6.0                 611            2
# ...

# %%
b.corr()
# Out:
#                                Temperature  Humidity     PM2.5      PM10  \
# Temperature                       1.000000  0.466456  0.323840  0.425690
# Humidity                          0.466456  1.000000  0.273366  0.359156
# PM2.5                             0.323840  0.273366  1.000000  0.973005
# PM10                              0.425690  0.359156  0.973005  1.000000
# NO2                               0.591969  0.491977  0.333004  0.439916
# SO2                               0.568082  0.459804  0.299582  0.401849
# CO                                0.685258  0.567540  0.395179  0.518895
# Proximity_to_Industrial_Areas    -0.589564 -0.479646 -0.315766 -0.425018
# Population_Density                0.481692  0.411630  0.278957  0.365734
# Air Quality                       0.152046  0.148279  0.069126  0.106942
#
#                                     NO2       SO2        CO  \
# Temperature                    0.591969  0.568082  0.685258
# ...

# %%
X = b.copy()
X.drop(["Air Quality"], axis = 1, inplace = True)
Y = b["Air Quality"]

# %%
from sklearn.decomposition import PCA

# %%
a = PCA()
x = a.fit_transform(X)
x.shape
# Out:
# (5000, 9)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, Y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)
n = RandomForestClassifier()
n.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict_train = n.predict(x_train)
print(cr(y_true = y_train, y_pred = y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       344
#            1       1.00      1.00      1.00      1404
#            2       1.00      1.00      1.00      1042
#            3       1.00      1.00      1.00       710
#
#     accuracy                           1.00      3500
#    macro avg       1.00      1.00      1.00      3500
# weighted avg       1.00      1.00      1.00      3500

# %%
y_predict_test = n.predict(x_test)
print(cr(y_true = y_test, y_pred = y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75       156
#            1       0.97      0.97      0.97       596
#            2       0.86      0.91      0.89       458
#            3       0.75      0.77      0.76       290
#
#     accuracy                           0.88      1500
#    macro avg       0.86      0.83      0.84      1500
# weighted avg       0.88      0.88      0.88      1500

# %%
cm(y_true = y_train, y_pred = y_predict_train)
# Out:
# array([[ 344,    0,    0,    0],
#        [   0, 1404,    0,    0],
#        [   0,    0, 1042,    0],
#        [   0,    0,    0,  710]], dtype=int64)
